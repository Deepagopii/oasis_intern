# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
sales=pd.read_csv('/content/sales.zip')

# %%
sales.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
sales.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
sales.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
sales.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
sales.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
sales.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
sns.scatterplot(x=sales['TV'],y=sales['Sales'])
plt.show()

# %%
sns.scatterplot(x=sales['Radio'],y=sales['Sales'])
plt.show()

# %%
sns.scatterplot(x=sales['Newspaper'],y=sales['Sales'])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(sales['Sales'], bins=10)
plt.show()

# %%
sns.boxplot(data=sales)
plt.title('Box Plot')
plt.show()

# %%
sns.violinplot(data=sales, y='TV')
plt.show()

# %%
sns.violinplot(data=sales, y='Radio')
plt.show()

# %%
sns.violinplot(data=sales, y='Newspaper')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.violinplot(data=sales, y='TV', x='Sales', split=True)
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.swarmplot(data=sales, x='Radio', y='Newspaper', hue='Sales')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.violinplot(data=sales, y='Sales')
plt.show()

# %%
correlation_matrix = sales.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
X = sales[['TV', 'Newspaper', 'Radio']]
y = sales['Sales']

# %%
X.head()
# Out:
#       TV  Newspaper  Radio
# 0  230.1       69.2   37.8
# 1   44.5       45.1   39.3
# 2   17.2       69.3   45.9
# 3  151.5       58.5   41.3
# 4  180.8       58.4   10.8

# %%
y.head()
# Out:
# 0    22.1
# 1    10.4
# 2    12.0
# 3    16.5
# 4    17.9
# Name: Sales, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error



# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# Initialize the Random Forest Regressor
model = RandomForestRegressor(random_state=22)

# Train the model
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f'R2 Score: {r2}')
print(f'Mean Absolute Error: {mae}')
# Out:
# R2 Score: 0.9179693775430167
# Mean Absolute Error: 0.9279249999999983
