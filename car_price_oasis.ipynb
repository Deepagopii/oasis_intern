# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car_price=pd.read_csv('/content/car_price.zip')

# %%
car_price.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
car_price.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Selling_type Transmission  Owner
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0

# %%
car_price.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
car_price.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
car_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
car_price.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
car_price.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Driven_kms         int64
# Fuel_Type         object
# Selling_type      object
# Transmission      object
# Owner              int64
# dtype: object

# %%
car_price.duplicated().sum()
# Out:
# 2

# %%
car_price.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# ...

# %%
car_price['Selling_Price'].value_counts()
# Out:
# 0.45     8
# 0.60     8
# 5.25     7
# 4.50     7
# 0.20     6
#         ..
# 3.80     1
# 3.45     1
# 5.90     1
# 35.00    1
# 11.50    1
# Name: Selling_Price, Length: 156, dtype: int64

# %%
car_price['Present_Price'].value_counts()
# Out:
# 9.40     14
# 13.60    13
# 5.70      8
# 1.47      7
# 0.51      6
#          ..
# 36.23     1
# 18.54     1
# 7.27      1
# 15.04     1
# 12.50     1
# Name: Present_Price, Length: 148, dtype: int64

# %%
car_price['Driven_kms'].value_counts()
# Out:
# 45000    9
# 15000    9
# 40000    5
# 35000    5
# 50000    5
#         ..
# 1400     1
# 1200     1
# 4100     1
# 21700    1
# 5464     1
# Name: Driven_kms, Length: 206, dtype: int64

# %%
sns.countplot(x='Selling_type', data=car_price)
plt.show()

# %%
car_price['Transmission'].value_counts()
# Out:
# Manual       261
# Automatic     40
# Name: Transmission, dtype: int64

# %%
sns.countplot(x='Transmission', data=car_price)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Present_Price', y='Selling_Price',data=car_price, palette='viridis')

# Set labels and title
plt.xlabel('Present Price')
plt.ylabel('Selling Price')
plt.title('Scatter Plot: Present Price vs Selling Price')


# Show the plot
plt.show()
# Out:
# <ipython-input-26-e953ba31f7be>:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='Present_Price', y='Selling_Price',data=car_price, palette='viridis')

# %%
feature = 'Fuel_Type'

# Group the data by the selected feature and calculate the average selling price
grouped_data = car_price.groupby(feature)['Selling_Price'].mean()

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(grouped_data, labels=grouped_data.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.viridis.colors)
plt.title(f'Average Selling Price based on {feature}')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Show the plot
plt.show()

# %%
# Plotting the correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(car_price.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-30-b2d0ee302826>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(car_price.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)

# %%
plt.figure(figsize=(10, 6))
sns.histplot(car_price['Driven_kms'], bins=30, kde=True, color='skyblue')
plt.title('Histogram for Driven_kms')
plt.xlabel('Driven_kms')
plt.ylabel('Frequency')
plt.show()

# %%
top_25_cars = car_price['Car_Name'].value_counts().head(25)

# Plotting a pie chart for the top 25 car names
plt.figure(figsize=(10, 10))
top_25_cars.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Top 25 Car Names Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that the pie is drawn as a circle.
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D



# Get the top 10 car names (you can adjust the number)
top_cars = car_price['Car_Name'].value_counts().head(10)

# Create a 3D bar chart
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Plotting the bars
x_positions = range(len(top_cars))
ax.bar(x_positions, top_cars, zs=0, zdir='y', width=0.8, color='skyblue', alpha=0.8)

# Setting labels and title
ax.set_xlabel('Car Names')
ax.set_ylabel('Frequency')
ax.set_zlabel('Count')
ax.set_title('Top Car Names Distribution')

# Setting ticks and labels
ax.set_xticks(x_positions)
ax.set_xticklabels(top_cars.index, rotation=45, ha='right')

plt.show()

# %%
#Split the datset into features
X = car_price.drop('Selling_Price', axis=1)
y = car_price['Selling_Price']

# %%
# One-hot encoding categorical values into numerical values
X_encoded = pd.get_dummies(X, columns=['Fuel_Type', 'Selling_type', 'Transmission','Car_Name'], prefix=['Fuel', 'Selling', 'Transmission','Cars'])

# %%
#Splitting the dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# %%
#Train a Random Forest Model
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor(random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred_rf = rf_model.predict(X_test)

# %%
#Evaluating the Random Forest Model
mse_rf = mean_squared_error(y_test, y_pred_rf)
rmse_rf = sqrt(mse_rf)
print(f'Random Forest RMSE: {rmse_rf}')
# Out:
# Random Forest RMSE: 0.8724393833985933

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_test, y=y_pred_rf)
plt.xlabel('Actual Selling Price')
plt.ylabel('Predicted Selling Price (Random Forest)')
plt.title('Actual vs. Predicted Selling Price (Random Forest)')
plt.show()

# %%
plt.figure(figsize=(10, 6))

# Iterate through unique categories in 'Fuel_Type' and create scatter plots with different colors
for fuel_type in car_price['Fuel_Type'].unique():
    subset = car_price[car_price['Fuel_Type'] == fuel_type]
    sns.scatterplot(x=subset['Present_Price'], y=subset['Selling_Price'], label=fuel_type)

plt.xlabel('Actual Selling Price')
plt.ylabel('Predicted Selling Price (Random Forest)')
plt.title('Actual vs. Predicted Selling Price (Random Forest) - Different Colors for Fuel Types')
plt.legend(title='Fuel Type', loc='upper left')
plt.show()
