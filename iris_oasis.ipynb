# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
iris=pd.read_csv('/content/iris.zip')

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris.sample(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 3      4            4.6           3.1            1.5           0.2
# 123  124            6.3           2.7            4.9           1.8
# 149  150            5.9           3.0            5.1           1.8
# 12    13            4.8           3.0            1.4           0.1
# 127  128            6.1           3.0            4.9           1.8
# 63    64            6.1           2.9            4.7           1.4
# 130  131            7.4           2.8            6.1           1.9
# 71    72            6.1           2.8            4.0           1.3
# 54    55            6.5           2.8            4.6           1.5
# 103  104            6.3           2.9            5.6           1.8
#
#              Species
# 3        Iris-setosa
# 123   Iris-virginica
# 149   Iris-virginica
# 12       Iris-setosa
# 127   Iris-virginica
# 63   Iris-versicolor
# 130   Iris-virginica
# 71   Iris-versicolor
# 54   Iris-versicolor
# ...

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris.skew()
# Out:
# <ipython-input-46-21487a0f66e5>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris.skew()
# Id               0.000000
# SepalLengthCm    0.314911
# SepalWidthCm     0.334053
# PetalLengthCm   -0.274464
# PetalWidthCm    -0.104997
# dtype: float64

# %%
iris.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris = iris.drop('Id', axis=1)

# %%
#Lets understand the sepal length and sepal width relationship by using scatterplot from seaborn library
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', hue='Species', data=iris, )
plt.show()

# %%
#Lets understand the sepal length and sepal width relationship by using scatterplot from seaborn library
sns.scatterplot(x='PetalLengthCm', y='PetalWidthCm', hue='Species', data=iris, )
plt.show()

# %%
#We will see the plot between sepallength and petal width by plotting a Scatter plot between them.
sns.scatterplot(x='SepalLengthCm', y='PetalWidthCm', hue='Species', data=iris, )
plt.show()

# %%
iris.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'SepalLengthCm'}>,
#         <Axes: title={'center': 'SepalWidthCm'}>],
#        [<Axes: title={'center': 'PetalLengthCm'}>,
#         <Axes: title={'center': 'PetalWidthCm'}>]], dtype=object)

# %%
plt.figure(figsize=(20,6))
plt.title("Species Vs Sepal length")
sns.barplot(data=iris,x='Species',y='SepalLengthCm')
# Out:
# <Axes: title={'center': 'Species Vs Sepal length'}, xlabel='Species', ylabel='SepalLengthCm'>

# %%
plt.figure(figsize=(20,6))
plt.title("Species Vs Sepal width")
sns.barplot(data=iris,x='Species',y='SepalWidthCm')
# Out:
# <Axes: title={'center': 'Species Vs Sepal width'}, xlabel='Species', ylabel='SepalWidthCm'>

# %%
plt.figure(figsize=(20,6))
plt.title("Species Vs petal length")
sns.barplot(data=iris,x='Species',y='PetalLengthCm')
# Out:
# <Axes: title={'center': 'Species Vs petal length'}, xlabel='Species', ylabel='PetalLengthCm'>

# %%
plt.figure(figsize=(20,6))
plt.title("Species Vs petal width")
sns.barplot(data=iris,x='Species',y='PetalWidthCm')
# Out:
# <Axes: title={'center': 'Species Vs petal width'}, xlabel='Species', ylabel='PetalWidthCm'>

# %%
plt.figure(figsize=(10,5))
sns.heatmap(iris.corr(),cmap='YlGnBu',annot=True)
# Out:
# <ipython-input-60-d36c118eba4a>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(iris.corr(),cmap='YlGnBu',annot=True)
# <Axes: >

# %%
x = iris.drop(['Species'],axis=1)
y = iris['Species']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.2)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import accuracy_score

# %%
pred = model.predict(x_test)
accuracy_score(pred,y_test)
# Out:
# 0.9666666666666667

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier


# Assuming you have already loaded the dataset into 'iris' DataFrame
# and trained the model as shown in your previous code

# User input for iris measurements
sepal_length = float(input("Enter sepal length: "))
sepal_width = float(input("Enter sepal width: "))
petal_length = float(input("Enter petal length: "))
petal_width = float(input("Enter petal width: "))

# Create a DataFrame with the user input
new_measurement = pd.DataFrame([[sepal_length, sepal_width, petal_length, petal_width]], columns=x.columns)

# Make predictions for the new measurements
predicted_species = model.predict(new_measurement)

# Display the predicted species name
print(f"Predicted Species: {predicted_species[0]}")
# Out:
# Enter sepal length: 5.1
# Enter sepal width: 2.5
# Enter petal length: 3
# Enter petal width: 1.1
# Predicted Species: Iris-versicolor
